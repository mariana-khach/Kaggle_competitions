# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# ...

# %%
df[df["date"]>"2015-11-01"].to_csv("train_2015.csv",index=False)

# %%
df5=pd.read_csv("train_2015.csv")

# %%
df5
# Out:
#               id        date  store_nbr                      family     sales  \
# 0        1299078  2015-01-02          1                  AUTOMOTIVE     2.000
# 1        1299079  2015-01-02          1                   BABY CARE     0.000
# 2        1299080  2015-01-02          1                      BEAUTY     3.000
# 3        1299081  2015-01-02          1                   BEVERAGES   794.000
# 4        1299082  2015-01-02          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 1701805  3000883  2017-08-15          9                     POULTRY   438.133
# 1701806  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 1701807  3000885  2017-08-15          9                     PRODUCE  2419.729
# 1701808  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 1701809  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# ...
